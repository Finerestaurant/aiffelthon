# %%
from model import SampleCNN
import flax.linen as nn


import jax
import numpy as np
import jax.numpy as jnp

# %%
key  =jax.random.PRNGKey(42)

nn.tabulate(SampleCNN(), {'params': key, 'dropout':key},)(jnp.ones((16,48,1876,1)))
# Out:
#                                     SampleCNN Summary
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ path         ┃ outputs             ┃ batch_stats        ┃ params                      ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Inputs       │ float32[16,48,1876] │                    │                             │
# ├──────────────┼─────────────────────┼────────────────────┼─────────────────────────────┤
# │ BatchNorm_0  │ float32[16,16,128]  │ mean: float32[128] │ bias: float32[128]          │
# │              │                     │ var: float32[128]  │ scale: float32[128]         │
# │              │                     │                    │                             │
# │              │                     │ 256 (1.0 KB)       │ 256 (1.0 KB)                │
# ├──────────────┼─────────────────────┼────────────────────┼─────────────────────────────┤
# ...
